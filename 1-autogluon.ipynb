# %%
import pandas as pd

df = pd.read_csv('data/train.csv')
df
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0        NaN                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               NaN        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# 1                3.0                        No                 10.0
# 2                0.0                       NaN                  3.0
# 3                3.0                        No                 11.0
# 4                4.0                        No                 13.0
# ...              ...                       ...                  ...
# 18519            3.0                        No                  9.0
# 18520            7.0                        No                  6.0
# 18521            1.0                       Yes                  1.0
# 18522            0.0                       Yes                  5.0
# 18523            6.0                        No                  4.0
#
#        Post_frequency Personality
# 0                 5.0   Extrovert
# 1                 8.0   Extrovert
# 2                 0.0   Introvert
# 3                 5.0   Extrovert
# 4                 NaN   Extrovert
# ...               ...         ...
# 18519             7.0   Extrovert
# 18520             5.0   Extrovert
# 18521             NaN   Introvert
# 18522             2.0   Introvert
# 18523             7.0   Extrovert
#
# [18524 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor

train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)
train, val = TabularDataset(train_df), TabularDataset(val_df)

# %%
predictor = TabularPredictor(
    label='Personality',
    problem_type='binary',
    path='autogluon_models',
    eval_metric='f1',
    positive_class='Introvert',
    verbosity=2,
).fit(
    train.sample(frac=0.8, random_state=42),
    #hyperparameters='toy',
    presets='best_quality',
    calibrate_decision_threshold='auto',
    dynamic_stacking=True,
    ag_args_fit={
        'num_cpus': 10,
    },
    time_limit=1200,
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="autogluon_models"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.11.11
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 24.5.0: Tue Apr 22 19:54:43 PDT 2025; root:xnu-11417.121.6~2/RELEASE_ARM64_T8132
# CPU Count:          10
# Memory Avail:       20.65 GB / 32.00 GB (64.5%)
# Disk Space Avail:   116.98 GB / 926.35 GB (12.6%)
# ===================================================
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 300s of the 1200s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-07-14 11:45:10,282	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/autogluon_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=13827) Running DyStack sub-fit ...
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/utils.py:97: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_dystack pid=13827)   import pkg_resources
# (_dystack pid=13827) Beginning AutoGluon training ... Time limit = 299s
# (_dystack pid=13827) AutoGluon will save models to "/Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/autogluon_models/ds_sub_fit/sub_fit_ho"
# (_dystack pid=13827) Train Data Rows:    10537
# (_dystack pid=13827) Train Data Columns: 8
# (_dystack pid=13827) Label Column:       Personality
# (_dystack pid=13827) Problem Type:       binary
# (_dystack pid=13827) Preprocessing data ...
# (_dystack pid=13827) Selected class <--> label mapping:  class 1 = Introvert, class 0 = Extrovert
# (_dystack pid=13827) Using Feature Generators to preprocess the data ...
# (_dystack pid=13827) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=13827) 	Available Memory:                    20630.05 MB
# (_dystack pid=13827) 	Train Data (Original)  Memory Usage: 1.63 MB (0.0% of available memory)
# (_dystack pid=13827) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=13827) 	Stage 1 Generators:
# (_dystack pid=13827) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=13827) 	Stage 2 Generators:
# (_dystack pid=13827) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=13827) 	Stage 3 Generators:
# (_dystack pid=13827) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=13827) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=13827) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=13827) 	Stage 4 Generators:
# (_dystack pid=13827) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=13827) 	Stage 5 Generators:
# (_dystack pid=13827) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=13827) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=13827) 		('float', [])  : 5 | ['Time_spent_Alone', 'Social_event_attendance', 'Going_outside', 'Friends_circle_size', 'Post_frequency']
# (_dystack pid=13827) 		('int', [])    : 1 | ['id']
# (_dystack pid=13827) 		('object', []) : 2 | ['Stage_fear', 'Drained_after_socializing']
# (_dystack pid=13827) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=13827) 		('category', []) : 2 | ['Stage_fear', 'Drained_after_socializing']
# (_dystack pid=13827) 		('float', [])    : 5 | ['Time_spent_Alone', 'Social_event_attendance', 'Going_outside', 'Friends_circle_size', 'Post_frequency']
# (_dystack pid=13827) 		('int', [])      : 1 | ['id']
# (_dystack pid=13827) 	0.0s = Fit runtime
# (_dystack pid=13827) 	8 features in original data used to generate 8 features in processed data.
# (_dystack pid=13827) 	Train Data (Processed) Memory Usage: 0.50 MB (0.0% of available memory)
# (_dystack pid=13827) Data preprocessing and feature engineering runtime = 0.02s ...
# (_dystack pid=13827) AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# (_dystack pid=13827) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=13827) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=13827) User-specified model hyperparameters to be fit:
# (_dystack pid=13827) {
# (_dystack pid=13827) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=13827) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=13827) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=13827) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=13827) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=13827) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=13827) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=13827) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=13827) }
# (_dystack pid=13827) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=13827) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=13827) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 198.94s of the 298.47s of remaining time.
# (_dystack pid=13827) 	0.6889	 = Validation score   (f1)
# (_dystack pid=13827) 	0.01s	 = Training   runtime
# (_dystack pid=13827) 	0.01s	 = Validation runtime
# (_dystack pid=13827) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 198.19s of the 297.73s of remaining time.
# (_dystack pid=13827) 	0.7564	 = Validation score   (f1)
# (_dystack pid=13827) 	0.01s	 = Training   runtime
# (_dystack pid=13827) 	0.01s	 = Validation runtime
# (_dystack pid=13827) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 198.16s of the 297.70s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# (_dystack pid=13827) 	0.9417	 = Validation score   (f1)
# (_dystack pid=13827) 	19.3s	 = Training   runtime
# (_dystack pid=13827) 	0.02s	 = Validation runtime
# (_dystack pid=13827) Fitting model: LightGBM_BAG_L1 ... Training model for up to 178.08s of the 277.62s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# (_dystack pid=13827) 	0.9401	 = Validation score   (f1)
# (_dystack pid=13827) 	19.59s	 = Training   runtime
# (_dystack pid=13827) 	0.01s	 = Validation runtime
# (_dystack pid=13827) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 157.70s of the 257.24s of remaining time.
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
# (_dystack pid=13827)   warnings.warn(
# (_dystack pid=13827) 	0.9383	 = Validation score   (f1)
# (_dystack pid=13827) 	0.42s	 = Training   runtime
# (_dystack pid=13827) 	0.14s	 = Validation runtime
# (_dystack pid=13827) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 157.07s of the 256.60s of remaining time.
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
# (_dystack pid=13827)   warnings.warn(
# (_dystack pid=13827) 	0.9387	 = Validation score   (f1)
# (_dystack pid=13827) 	0.35s	 = Training   runtime
# (_dystack pid=13827) 	0.14s	 = Validation runtime
# (_dystack pid=13827) Fitting model: CatBoost_BAG_L1 ... Training model for up to 156.52s of the 256.06s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=1.90%)
# (_ray_fit pid=14003) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14003)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14031) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=14031)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 3x across cluster]
# (_ray_fit pid=14054) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 3x across cluster]
# (_ray_fit pid=14054)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 3x across cluster]
# (_dystack pid=13827) 	0.9392	 = Validation score   (f1)
# (_dystack pid=13827) 	16.54s	 = Training   runtime
# (_dystack pid=13827) 	0.01s	 = Validation runtime
# (_dystack pid=13827) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 139.21s of the 238.75s of remaining time.
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
# (_dystack pid=13827)   warnings.warn(
# (_dystack pid=13827) 	0.9393	 = Validation score   (f1)
# (_dystack pid=13827) 	0.29s	 = Training   runtime
# (_dystack pid=13827) 	0.15s	 = Validation runtime
# (_dystack pid=13827) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 138.72s of the 238.26s of remaining time.
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
# (_dystack pid=13827)   warnings.warn(
# (_dystack pid=13827) 	0.9389	 = Validation score   (f1)
# (_dystack pid=13827) 	0.26s	 = Training   runtime
# (_dystack pid=13827) 	0.15s	 = Validation runtime
# (_dystack pid=13827) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 138.25s of the 237.79s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.03%)
# (_ray_fit pid=14071) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 2x across cluster]
# (_ray_fit pid=14071)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 2x across cluster]
# (_ray_fit pid=14071) No improvement since epoch 4: early stopping
# (_ray_fit pid=14103) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 2x across cluster]
# (_ray_fit pid=14103)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 2x across cluster]
# (_ray_fit pid=14103) No improvement since epoch 7: early stopping
# (_ray_fit pid=14125) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 2x across cluster]
# (_ray_fit pid=14125)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 2x across cluster]
# (_ray_fit pid=14125) No improvement since epoch 4: early stopping
# (_ray_fit pid=14157) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 2x across cluster]
# (_ray_fit pid=14157)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 2x across cluster]
# (_dystack pid=13827) 	0.9415	 = Validation score   (f1)
# (_dystack pid=13827) 	29.47s	 = Training   runtime
# (_dystack pid=13827) 	0.05s	 = Validation runtime
# (_dystack pid=13827) Fitting model: XGBoost_BAG_L1 ... Training model for up to 108.01s of the 207.55s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.07%)
# (_ray_fit pid=14168) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14168)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14168) No improvement since epoch 5: early stopping
# (_ray_fit pid=14179) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:107: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14179)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14205) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:107: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 4x across cluster]
# (_ray_fit pid=14205)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 4x across cluster]
# (_dystack pid=13827) 	0.9411	 = Validation score   (f1)
# (_dystack pid=13827) 	11.45s	 = Training   runtime
# (_dystack pid=13827) 	0.19s	 = Validation runtime
# (_dystack pid=13827) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 95.67s of the 195.21s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.02%)
# (_dystack pid=13827) 	0.9407	 = Validation score   (f1)
# (_dystack pid=13827) 	30.28s	 = Training   runtime
# (_dystack pid=13827) 	0.03s	 = Validation runtime
# (_dystack pid=13827) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 64.56s of the 164.10s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.11%)
# (_ray_fit pid=14223) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:107: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 3x across cluster]
# (_ray_fit pid=14223)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 3x across cluster]
# (_ray_fit pid=14327) 	Ran out of time, early stopping on iteration 372. Best iteration is:
# (_ray_fit pid=14327) 	[209]	valid_set's binary_logloss: 0.162631	valid_set's f1: 0.936107
# (_ray_fit pid=14359) 	Ran out of time, early stopping on iteration 450. Best iteration is:
# (_ray_fit pid=14359) 	[158]	valid_set's binary_logloss: 0.126442	valid_set's f1: 0.945668
# (_dystack pid=13827) 	0.9406	 = Validation score   (f1)
# (_dystack pid=13827) 	50.65s	 = Training   runtime
# (_dystack pid=13827) 	0.02s	 = Validation runtime
# (_dystack pid=13827) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 13.06s of the 112.60s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=1.96%)
# (_ray_fit pid=14423) 	Ran out of time, early stopping on iteration 459. Best iteration is:
# (_ray_fit pid=14423) 	[229]	valid_set's binary_logloss: 0.162054	valid_set's f1: 0.933333
# (_ray_fit pid=14441) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14441)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14464) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 4x across cluster]
# (_ray_fit pid=14464)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 4x across cluster]
# (_dystack pid=13827) 	0.9394	 = Validation score   (f1)
# (_dystack pid=13827) 	10.89s	 = Training   runtime
# (_dystack pid=13827) 	0.01s	 = Validation runtime
# (_dystack pid=13827) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1.36s of the 100.90s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.02%)
# (_dystack pid=13827) 	Time limit exceeded... Skipping NeuralNetTorch_r79_BAG_L1.
# (_ray_fit pid=14477) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 3x across cluster]
# (_ray_fit pid=14477)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 3x across cluster]
# (_dystack pid=13827) Fitting model: WeightedEnsemble_L2 ... Training model for up to 298.48s of the 99.23s of remaining time.
# (_dystack pid=13827) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=13827) 	0.9417	 = Validation score   (f1)
# (_dystack pid=13827) 	0.29s	 = Training   runtime
# (_dystack pid=13827) 	0.0s	 = Validation runtime
# (_dystack pid=13827) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=13827) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 98.94s of the 98.92s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.07%)
# (_dystack pid=13827) 	0.9417	 = Validation score   (f1)
# (_dystack pid=13827) 	21.4s	 = Training   runtime
# (_dystack pid=13827) 	0.02s	 = Validation runtime
# (_dystack pid=13827) Fitting model: LightGBM_BAG_L2 ... Training model for up to 76.88s of the 76.86s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.07%)
# (_dystack pid=13827) 	0.9413	 = Validation score   (f1)
# (_dystack pid=13827) 	19.07s	 = Training   runtime
# (_dystack pid=13827) 	0.02s	 = Validation runtime
# (_dystack pid=13827) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 56.99s of the 56.97s of remaining time.
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
# (_dystack pid=13827)   warnings.warn(
# (_dystack pid=13827) 	0.9416	 = Validation score   (f1)
# (_dystack pid=13827) 	0.72s	 = Training   runtime
# (_dystack pid=13827) 	0.15s	 = Validation runtime
# (_dystack pid=13827) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 56.07s of the 56.05s of remaining time.
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
# (_dystack pid=13827)   warnings.warn(
# (_dystack pid=13827) 	0.9412	 = Validation score   (f1)
# (_dystack pid=13827) 	0.71s	 = Training   runtime
# (_dystack pid=13827) 	0.14s	 = Validation runtime
# (_dystack pid=13827) Fitting model: CatBoost_BAG_L2 ... Training model for up to 55.17s of the 55.15s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=2.11%)
# (_ray_fit pid=14636) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14636)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14664) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 3x across cluster]
# (_ray_fit pid=14664)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 3x across cluster]
# (_ray_fit pid=14682) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 3x across cluster]
# (_ray_fit pid=14682)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 3x across cluster]
# (_dystack pid=13827) 	0.9403	 = Validation score   (f1)
# (_dystack pid=13827) 	17.95s	 = Training   runtime
# (_dystack pid=13827) 	0.01s	 = Validation runtime
# (_dystack pid=13827) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 36.44s of the 36.42s of remaining time.
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
# (_dystack pid=13827)   warnings.warn(
# (_dystack pid=13827) 	0.9403	 = Validation score   (f1)
# (_dystack pid=13827) 	0.35s	 = Training   runtime
# (_dystack pid=13827) 	0.2s	 = Validation runtime
# (_dystack pid=13827) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 35.83s of the 35.81s of remaining time.
# (_dystack pid=13827) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
# (_dystack pid=13827)   warnings.warn(
# (_dystack pid=13827) 	0.9407	 = Validation score   (f1)
# (_dystack pid=13827) 	0.32s	 = Training   runtime
# (_dystack pid=13827) 	0.16s	 = Validation runtime
# (_dystack pid=13827) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 35.29s of the 35.27s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.07%)
# (_ray_fit pid=14699) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 2x across cluster]
# (_ray_fit pid=14699)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 2x across cluster]
# (_ray_fit pid=14699) No improvement since epoch 1: early stopping
# (_ray_fit pid=14705) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14705)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14716) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14716)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14716) No improvement since epoch 9: early stopping [repeated 2x across cluster]
# (_ray_fit pid=14738) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 2x across cluster]
# (_ray_fit pid=14738)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 2x across cluster]
# (_ray_fit pid=14749) No improvement since epoch 4: early stopping
# (_ray_fit pid=14749) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14749)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14760) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14760)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_dystack pid=13827) 	0.9417	 = Validation score   (f1)
# (_dystack pid=13827) 	30.56s	 = Training   runtime
# (_dystack pid=13827) 	0.07s	 = Validation runtime
# (_dystack pid=13827) Fitting model: XGBoost_BAG_L2 ... Training model for up to 3.93s of the 3.92s of remaining time.
# (_dystack pid=13827) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.12%)
# (_ray_fit pid=14760) No improvement since epoch 0: early stopping
# (_ray_fit pid=14771) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:131: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14771)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14782) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:107: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# (_ray_fit pid=14782)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel
# (_ray_fit pid=14798) /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/try_import.py:107: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81. [repeated 5x across cluster]
# (_ray_fit pid=14798)   from pkg_resources import parse_version  # pylint: disable=import-outside-toplevel [repeated 5x across cluster]
# (_dystack pid=13827) 	0.9404	 = Validation score   (f1)
# (_dystack pid=13827) 	8.52s	 = Training   runtime
# (_dystack pid=13827) 	0.02s	 = Validation runtime
# (_dystack pid=13827) Fitting model: WeightedEnsemble_L3 ... Training model for up to 298.48s of the -5.57s of remaining time.
# (_dystack pid=13827) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 1.0}
# (_dystack pid=13827) 	0.9417	 = Validation score   (f1)
# (_dystack pid=13827) 	0.44s	 = Training   runtime
# (_dystack pid=13827) 	0.0s	 = Validation runtime
# (_dystack pid=13827) AutoGluon training complete, total runtime = 304.52s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 2763.9 rows/s (1318 batch size)
# (_dystack pid=13827) Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# (_dystack pid=13827) Calibrating decision threshold to optimize metric f1 | Checking 51 thresholds...
# (_dystack pid=13827) Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# (_dystack pid=13827) 	Base Threshold: 0.500	| val: 0.9417
# (_dystack pid=13827) 	Best Threshold: 0.500	| val: 0.9417
# (_dystack pid=13827) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/autogluon_models/ds_sub_fit/sub_fit_ho")
# (_dystack pid=13827) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                       model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     NeuralNetTorch_BAG_L1       0.930370   0.940701          f1        0.046283       0.033880   30.282842                 0.046283                0.033880          30.282842            1       True         12
# 1   RandomForestEntr_BAG_L2       0.930370   0.941198          f1        0.853653       1.081825  190.206654                 0.036560                0.140640           0.705942            2       True         19
# 2     ExtraTreesGini_BAG_L1       0.928994   0.939277          f1        0.048391       0.150642    0.288511                 0.048391                0.150642           0.288511            1       True          8
# 3     ExtraTreesEntr_BAG_L1       0.928994   0.938888          f1        0.050300       0.149908    0.261887                 0.050300                0.149908           0.261887            1       True          9
# 4    NeuralNetFastAI_BAG_L1       0.928994   0.941522          f1        0.250562       0.051498   29.467433                 0.250562                0.051498          29.467433            1       True         10
# 5      LightGBMLarge_BAG_L1       0.928783   0.940592          f1        0.041139       0.019241   50.646778                 0.041139                0.019241          50.646778            1       True         13
# 6         LightGBMXT_BAG_L1       0.928783   0.941696          f1        0.082220       0.015602   19.299062                 0.082220                0.015602          19.299062            1       True          3
# 7       WeightedEnsemble_L2       0.928783   0.941696          f1        0.082666       0.016673   19.592546                 0.000446                0.001071           0.293484            2       True         15
# 8           LightGBM_BAG_L2       0.928783   0.941350          f1        0.836758       0.958666  208.573890                 0.019665                0.017481          19.073178            2       True         17
# 9   RandomForestGini_BAG_L2       0.928783   0.941566          f1        0.861311       1.089868  190.215789                 0.044218                0.148683           0.715077            2       True         18
# 10   NeuralNetFastAI_BAG_L2       0.927622   0.941737          f1        0.897320       1.008001  220.061048                 0.080227                0.066816          30.560336            2       True         23
# 11      WeightedEnsemble_L3       0.927622   0.941737          f1        0.897781       1.009206  220.505404                 0.000461                0.001205           0.444356            3       True         25
# 12          CatBoost_BAG_L2       0.927407   0.940290          f1        0.827018       0.949431  207.454594                 0.009925                0.008246          17.953882            2       True         20
# 13    ExtraTreesEntr_BAG_L2       0.927407   0.940680          f1        0.857504       1.101191  189.825396                 0.040411                0.160006           0.324684            2       True         22
# 14    ExtraTreesGini_BAG_L2       0.927407   0.940312          f1        0.864179       1.144346  189.846605                 0.047086                0.203161           0.345893            2       True         21
# 15           XGBoost_BAG_L1       0.927192   0.941133          f1        0.037259       0.187443   11.448152                 0.037259                0.187443          11.448152            1       True         11
# 16          CatBoost_BAG_L1       0.927192   0.939188          f1        0.124986       0.006903   16.538176                 0.124986                0.006903          16.538176            1       True          7
# 17        LightGBMXT_BAG_L2       0.927192   0.941717          f1        0.849572       0.963386  210.903733                 0.032479                0.022201          21.403021            2       True         16
# 18           XGBoost_BAG_L2       0.927192   0.940353          f1        0.850764       0.959962  198.025025                 0.033671                0.018777           8.524313            2       True         24
# 19  RandomForestEntr_BAG_L1       0.926036   0.938671          f1        0.039436       0.138925    0.354668                 0.039436                0.138925           0.354668            1       True          6
# 20  RandomForestGini_BAG_L1       0.926036   0.938326          f1        0.043004       0.142840    0.416647                 0.043004                0.142840           0.416647            1       True          5
# 21     CatBoost_r177_BAG_L1       0.925595   0.939405          f1        0.007323       0.006383   10.890863                 0.007323                0.006383          10.890863            1       True         14
# 22          LightGBM_BAG_L1       0.925595   0.940074          f1        0.019941       0.012981   19.594254                 0.019941                0.012981          19.594254            1       True          4
# 23    KNeighborsDist_BAG_L1       0.737564   0.756426          f1        0.013683       0.011892    0.005200                 0.013683                0.011892           0.005200            1       True          2
# 24    KNeighborsUnif_BAG_L1       0.647059   0.688948          f1        0.012566       0.013047    0.006239                 0.012566                0.013047           0.006239            1       True          1
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	308s	 = DyStack   runtime |	892s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/autogluon/common/utils/utils.py:97: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Beginning AutoGluon training ... Time limit = 892s
# AutoGluon will save models to "/Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/autogluon_models"
# Train Data Rows:    11855
# Train Data Columns: 8
# Label Column:       Personality
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = Introvert, class 0 = Extrovert
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    19491.77 MB
# 	Train Data (Original)  Memory Usage: 1.83 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 5 | ['Time_spent_Alone', 'Social_event_attendance', 'Going_outside', 'Friends_circle_size', 'Post_frequency']
# 		('int', [])    : 1 | ['id']
# 		('object', []) : 2 | ['Stage_fear', 'Drained_after_socializing']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 2 | ['Stage_fear', 'Drained_after_socializing']
# 		('float', [])    : 5 | ['Time_spent_Alone', 'Social_event_attendance', 'Going_outside', 'Friends_circle_size', 'Post_frequency']
# 		('int', [])      : 1 | ['id']
# 	0.0s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.57 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# ...
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 891.82s of the 891.82s of remaining time.
# 	0.7246	 = Validation score   (f1)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 891.22s of the 891.21s of remaining time.
# 	0.7798	 = Validation score   (f1)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 891.18s of the 891.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# 	0.9399	 = Validation score   (f1)
# 	18.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 871.94s of the 871.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# 	0.9391	 = Validation score   (f1)
# 	16.96s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 854.20s of the 854.19s of remaining time.
# /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.9372	 = Validation score   (f1)
# 	0.39s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 853.58s of the 853.58s of remaining time.
# /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.9375	 = Validation score   (f1)
# 	0.34s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 853.03s of the 853.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=1.99%)
# 	0.9391	 = Validation score   (f1)
# 	21.37s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 830.89s of the 830.89s of remaining time.
# /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.9381	 = Validation score   (f1)
# 	0.37s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 830.23s of the 830.23s of remaining time.
# /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.9378	 = Validation score   (f1)
# 	0.31s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 829.65s of the 829.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# 	0.9408	 = Validation score   (f1)
# 	37.64s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 791.18s of the 791.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.07%)
# 	0.9391	 = Validation score   (f1)
# 	10.48s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 779.70s of the 779.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9402	 = Validation score   (f1)
# 	29.08s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 749.77s of the 749.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.12%)
# 	0.9385	 = Validation score   (f1)
# 	48.59s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 700.13s of the 700.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=2.02%)
# 	0.9394	 = Validation score   (f1)
# 	12.37s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 686.92s of the 686.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9404	 = Validation score   (f1)
# 	49.64s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 636.36s of the 636.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.06%)
# 	0.9394	 = Validation score   (f1)
# 	27.86s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 607.46s of the 607.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# 	0.9408	 = Validation score   (f1)
# 	76.09s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 530.48s of the 530.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=2.10%)
# 	0.9384	 = Validation score   (f1)
# 	20.52s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 508.89s of the 508.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.03%)
# 	0.9394	 = Validation score   (f1)
# 	13.82s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 494.13s of the 494.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9402	 = Validation score   (f1)
# 	46.98s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 446.32s of the 446.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.21%)
# 	0.9393	 = Validation score   (f1)
# 	17.36s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 427.66s of the 427.66s of remaining time.
# /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.9376	 = Validation score   (f1)
# 	0.42s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 426.94s of the 426.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=2.16%)
# 	0.9394	 = Validation score   (f1)
# 	13.25s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 412.77s of the 412.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# 	0.9402	 = Validation score   (f1)
# 	23.41s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 388.44s of the 388.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=2.35%)
# 	0.9389	 = Validation score   (f1)
# 	19.31s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 367.93s of the 367.93s of remaining time.
# /Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/.venv/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.9365	 = Validation score   (f1)
# 	0.82s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 366.81s of the 366.80s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.13%)
# 	0.9398	 = Validation score   (f1)
# 	50.32s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 315.58s of the 315.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# 	0.9406	 = Validation score   (f1)
# 	87.84s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 226.80s of the 226.80s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.07%)
# 	0.9398	 = Validation score   (f1)
# 	11.44s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 214.02s of the 214.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9402	 = Validation score   (f1)
# 	73.92s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 139.24s of the 139.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.10%)
# 	0.9397	 = Validation score   (f1)
# 	34.76s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 103.38s of the 103.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.02%)
# 	0.9404	 = Validation score   (f1)
# 	48.09s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 54.38s of the 54.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=2.27%)
# 	0.9387	 = Validation score   (f1)
# 	19.54s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 33.66s of the 33.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=0.04%)
# 	0.9401	 = Validation score   (f1)
# 	40.37s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the -7.82s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# 	0.9408	 = Validation score   (f1)
# 	0.8s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 900.49s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 18498.3 rows/s (1482 batch size)
# Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# Calibrating decision threshold to optimize metric f1 | Checking 51 thresholds...
# Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# 	Base Threshold: 0.500	| val: 0.9408
# 	Best Threshold: 0.500	| val: 0.9408
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/clementcouchevellou/Documents/Personal projects/Predict-the-Introverts-from-the-Extroverts/autogluon_models")

# %%
predictor.leaderboard(val, extra_metrics=['f1', 'roc_auc', 'accuracy'])
# Out:
#                           model  score_test        f1   roc_auc  accuracy  \
# 0   NeuralNetFastAI_r102_BAG_L1    0.938559  0.938559  0.965194  0.968691
# 1     NeuralNetTorch_r30_BAG_L1    0.938559  0.938559  0.964600  0.968691
# 2   NeuralNetFastAI_r191_BAG_L1    0.938559  0.938559  0.965574  0.968691
# 3        NeuralNetFastAI_BAG_L1    0.938559  0.938559  0.968143  0.968691
# 4           WeightedEnsemble_L2    0.938559  0.938559  0.968143  0.968691
# 5       RandomForestGini_BAG_L1    0.938494  0.938494  0.963232  0.968691
# 6       RandomForestEntr_BAG_L1    0.938494  0.938494  0.963347  0.968691
# 7          CatBoost_r177_BAG_L1    0.937997  0.937997  0.965845  0.968421
# 8           CatBoost_r13_BAG_L1    0.937997  0.937997  0.966252  0.968421
# 9               CatBoost_BAG_L1    0.937997  0.937997  0.966523  0.968421
# 10        ExtraTreesGini_BAG_L1    0.937997  0.937997  0.962589  0.968421
# 11        ExtraTreesEntr_BAG_L1    0.937997  0.937997  0.964273  0.968421
# 12  NeuralNetFastAI_r145_BAG_L1    0.937997  0.937997  0.967521  0.968421
# 13   NeuralNetFastAI_r11_BAG_L1    0.937997  0.937997  0.962881  0.968421
# 14          CatBoost_r50_BAG_L1    0.937931  0.937931  0.966497  0.968421
# 15           CatBoost_r9_BAG_L1    0.937931  0.937931  0.965356  0.968421
# 16         LightGBM_r130_BAG_L1    0.937865  0.937865  0.965049  0.968421
# 17         CatBoost_r137_BAG_L1    0.937434  0.937434  0.966542  0.968151
# 18     RandomForest_r195_BAG_L1    0.937434  0.937434  0.961360  0.968151
# 19        NeuralNetTorch_BAG_L1    0.937434  0.937434  0.964869  0.968151
# 20    NeuralNetTorch_r79_BAG_L1    0.937434  0.937434  0.963306  0.968151
# 21    NeuralNetTorch_r86_BAG_L1    0.937434  0.937434  0.966053  0.968151
# 22            LightGBMXT_BAG_L1    0.937434  0.937434  0.967704  0.968151
# 23           XGBoost_r89_BAG_L1    0.937367  0.937367  0.966102  0.968151
# 24           XGBoost_r33_BAG_L1    0.937167  0.937167  0.964945  0.968151
# 25         LightGBM_r188_BAG_L1    0.936803  0.936803  0.967439  0.967881
# 26               XGBoost_BAG_L1    0.936668  0.936668  0.965561  0.967881
# 27         LightGBM_r131_BAG_L1    0.936668  0.936668  0.964441  0.967881
# 28    NeuralNetTorch_r22_BAG_L1    0.936306  0.936306  0.962630  0.967611
# 29          LightGBM_r96_BAG_L1    0.936238  0.936238  0.968680  0.967611
# 30              LightGBM_BAG_L1    0.936170  0.936170  0.964982  0.967611
# 31        ExtraTrees_r42_BAG_L1    0.935741  0.935741  0.964762  0.967341
# 32         LightGBMLarge_BAG_L1    0.933831  0.933831  0.964658  0.966532
# 33        KNeighborsDist_BAG_L1    0.789976  0.789976  0.930548  0.904993
# 34        KNeighborsUnif_BAG_L1    0.744244  0.744244  0.920503  0.889069
#
#     score_val eval_metric  pred_time_test  pred_time_val   fit_time  \
# 0    0.940160          f1        0.094344       0.047871  23.410725
# 1    0.940235          f1        0.164645       0.070922  73.919480
# 2    0.940754          f1        0.296213       0.100539  76.086188
# 3    0.940754          f1        0.317661       0.079839  37.639325
# 4    0.940754          f1        0.318470       0.082048  38.436004
# 5    0.937163          f1        0.053875       0.154715   0.391240
# 6    0.937510          f1        0.056112       0.155004   0.339966
# 7    0.939389          f1        0.009529       0.007858  12.367815
# 8    0.938929          f1        0.015597       0.010357  19.314137
# 9    0.939082          f1        0.036533       0.009837  21.368592
# 10   0.938122          f1        0.070340       0.226772   0.366756
# 11   0.937796          f1        0.100002       0.206102   0.309771
# 12   0.940639          f1        0.377655       0.149655  87.840485
# 13   0.940101          f1        0.435979       0.159630  40.367890
# 14   0.938736          f1        0.017657       0.015933  19.537880
# 15   0.938409          f1        0.025763       0.017157  20.522604
# 16   0.939716          f1        0.108296       0.021550  34.755947
# 17   0.939389          f1        0.010689       0.008856  13.249898
# 18   0.936469          f1        0.068325       0.238670   0.824067
# 19   0.940216          f1        0.094043       0.045443  29.076411
# 20   0.940369          f1        0.122633       0.058127  49.643078
# 21   0.940428          f1        0.134587       0.059844  48.092546
# 22   0.939909          f1        0.179847       0.014743  18.454916
# 23   0.939850          f1        0.087781       0.020352  11.436807
# 24   0.939310          f1        0.205728       0.031888  17.361125
# 25   0.939810          f1        0.135940       0.024153  50.319631
# 26   0.939116          f1        0.051832       0.015476  10.475213
# 27   0.939424          f1        0.111934       0.022768  27.856290
# 28   0.940196          f1        0.132547       0.069117  46.984378
# 29   0.939369          f1        0.042934       0.012793  13.823367
# 30   0.939116          f1        0.020957       0.010422  16.959869
# 31   0.937561          f1        0.087676       0.227811   0.422268
# 32   0.938482          f1        0.085974       0.017411  48.587022
# 33   0.779779          f1        0.015109       0.014528   0.005680
# 34   0.724576          f1        0.015203       0.014849   0.006056
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.094344                0.047871          23.410725
# 1                  0.164645                0.070922          73.919480
# 2                  0.296213                0.100539          76.086188
# 3                  0.317661                0.079839          37.639325
# 4                  0.000809                0.002209           0.796679
# 5                  0.053875                0.154715           0.391240
# 6                  0.056112                0.155004           0.339966
# 7                  0.009529                0.007858          12.367815
# 8                  0.015597                0.010357          19.314137
# 9                  0.036533                0.009837          21.368592
# 10                 0.070340                0.226772           0.366756
# 11                 0.100002                0.206102           0.309771
# 12                 0.377655                0.149655          87.840485
# 13                 0.435979                0.159630          40.367890
# 14                 0.017657                0.015933          19.537880
# 15                 0.025763                0.017157          20.522604
# 16                 0.108296                0.021550          34.755947
# 17                 0.010689                0.008856          13.249898
# 18                 0.068325                0.238670           0.824067
# 19                 0.094043                0.045443          29.076411
# 20                 0.122633                0.058127          49.643078
# 21                 0.134587                0.059844          48.092546
# 22                 0.179847                0.014743          18.454916
# 23                 0.087781                0.020352          11.436807
# 24                 0.205728                0.031888          17.361125
# 25                 0.135940                0.024153          50.319631
# 26                 0.051832                0.015476          10.475213
# 27                 0.111934                0.022768          27.856290
# 28                 0.132547                0.069117          46.984378
# 29                 0.042934                0.012793          13.823367
# 30                 0.020957                0.010422          16.959869
# 31                 0.087676                0.227811           0.422268
# 32                 0.085974                0.017411          48.587022
# 33                 0.015109                0.014528           0.005680
# 34                 0.015203                0.014849           0.006056
#
#     stack_level  can_infer  fit_order
# 0             1       True         24
# 1             1       True         30
# 2             1       True         17
# 3             1       True         10
# 4             2       True         35
# 5             1       True          5
# 6             1       True          6
# 7             1       True         14
# 8             1       True         25
# 9             1       True          7
# 10            1       True          8
# 11            1       True          9
# 12            1       True         28
# 13            1       True         34
# 14            1       True         33
# 15            1       True         18
# 16            1       True         31
# 17            1       True         23
# 18            1       True         26
# 19            1       True         12
# 20            1       True         15
# 21            1       True         32
# 22            1       True          3
# 23            1       True         29
# 24            1       True         21
# 25            1       True         27
# 26            1       True         11
# 27            1       True         16
# 28            1       True         20
# 29            1       True         19
# 30            1       True          4
# 31            1       True         22
# 32            1       True         13
# 33            1       True          2
# 34            1       True          1

# %%
test = TabularDataset('data/test.csv')
test_predictions = predictor.predict(test)
test_predictions
# Out:
# Loaded data from: data/test.csv | Columns = 8 / 8 | Rows = 6175 -> 6175
# 0       Extrovert
# 1       Introvert
# 2       Extrovert
# 3       Extrovert
# 4       Introvert
#           ...
# 6170    Extrovert
# 6171    Introvert
# 6172    Extrovert
# 6173    Extrovert
# 6174    Introvert
# Name: Personality, Length: 6175, dtype: object

# %%
sub = pd.read_csv('data/sample_submission.csv')
sub['Personality'] = test_predictions
sub.to_csv('submission.csv', index=False)
